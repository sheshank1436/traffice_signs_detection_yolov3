# %% [markdown]
# <a href="https://colab.research.google.com/github/sheshank1436/traffice_signs_detection_yolov3/blob/main/traffic_signs_detection_training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount the drive
from google.colab import drive
drive.mount('/content/gdrive')
# !ln -s /content/gdrive/My\ Drive/ /mydrive
# !ls /mydrive
# Out:
# Mounted at /content/gdrive
# 'Colab Notebooks'   darknet	    'My Drive'	 yolo1
#  cube		    darknet-master   pdf	 yolov3
#  cubes_yolo	   'img_(162).jpg'   test.jpeg	 yolov3-tiger

# %%
#change the directory to the path where your project files are present

# %cd /content/gdrive/MyDrive/darknet
# Out:
# /content/gdrive/MyDrive/darknet

# %%
#execute the makefile
#if the makefile doesn't execute execute the below two cells else let it be as it is
# !make
# Out:
# chmod +x *.sh

# %%
#!make &> compile.log

# %%
#!chmod +x ./darknet

# %%
#the below code is used to add the absolute path of input images in to the train.txt
#though we added the paths of the images in the train.txt and uploaded to google drive
#the paths were not identified so i used the below code to change the paths in train.txt
import glob
images_list = glob.glob(r"/content/gdrive/MyDrive/darknet/data/traffic_images/*.jpg")
print(images_list)
# Out:
# ['/content/gdrive/MyDrive/darknet/data/traffic_images/00896.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00893.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00894.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00898.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00899.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00228.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00270.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00253.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00254.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00268.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00224.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00238.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00271.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00242.jpg', '/content/gdrive/MyDrive/darknet/data/traffic_images/00267.jpg', '/content/gdrive/MyDri
# ...

# %%
#Create training.txt file and write the paths into that file
file = open("data/traffic_train.txt", "w") 
file.write("\n".join(images_list)) 
file.close()

# %%
# Start the training
# !./darknet detector train data/traffic_data.data cfg/yolov3_traffic_train.cfg  darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.906243), count: 1, class_loss = 0.000000, iou_loss = 0.004828, total_loss = 0.004828
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.525333), count: 2, class_loss = 0.031735, iou_loss = 0.290730, total_loss = 0.322465
#  total_bbox = 238549, rewritten_bbox = 0.134144 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 0.000000, iou_loss = 0.000000, total_loss = 0.000000
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = 0.000017, iou_loss = 0.000000, total_loss = 0.000017
# ...
